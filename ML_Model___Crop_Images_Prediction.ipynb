# %% [markdown]
# <a href="https://colab.research.google.com/github/gwegayhu/dashboards-app/blob/master/ML_Model___Crop_Images_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown

import json
import pandas as pd
import os
import gdown
import pandas as pd
import io

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# 1. Data Extraction and Transformation
# Download the file from Google Drive using the correct ID
# Get the Google Drive file ID from the URL
file_id = '1iBKEawZyX_S68hq3vh0kmyoExDnyIkqb'  # Extracted from the original URL
output = 'vegalite_1736783450.3959472_zone_characteristics_bar_chart.json'

# Download using the file ID
gdown.download(id=file_id, output=output, quiet=False)

# Now you can access the file locally
file_path = os.path.join(os.getcwd(), output)

# Initialize df to None to handle cases where it might not be created
df = None

if os.path.exists(file_path):
    # Check if the file is empty
    if os.stat(file_path).st_size == 0:
        print("Error: Downloaded file is empty.")
    else:  # Continue only if the file is not empty
        try:
            with open(file_path, 'r') as f:
                data = json.load(f)
            df = pd.DataFrame(data) # df is created here
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}")
            # You might want to print the first few lines of the file to debug
            with open(file_path, 'r') as f:
                print("First few lines of the file:")
                for i in range(5):
                    print(f.readline())
else:
    print(f"Error: File not found at {file_path}")
    # Handle the error, e.g., exit the script or use a default dataset
    # ...

# Check if df was created before proceeding
if df is not None:
    print("Shape of the dataset:", df.shape)
    display(df.head())
    print("\nDataset Information:")
    print(df.info())
    print("\nStatistical Summary:")
    display(df.describe().T)
else:
    print("Error: DataFrame 'df' was not created. Check file download and processing.")



# Load the data as a string, assuming it's the content you provided
data_string = """0,/kaggle/input/kag2/sugarcane/sugarcane037ahs.jpeg,sugarcane,3
1,/kaggle/input/kag2/sugarcane/sugarcane034a.jpeg,sugarcane,3
2,/kaggle/input/kag2/sugarcane/sugarcane032arot.jpeg,sugarcane,3
3,/kaggle/input/kag2/sugarcane/sugarcane036ahs.jpeg,sugarcane,3"""

# Use StringIO to create a file-like object from the string
data_io = io.StringIO(data_string)

# Read the data using pd.read_csv, specifying the delimiter and escapechar
try:
    df = pd.read_csv(data_io, header=None, names=['index', 'path', 'label', 'class'], delimiter=',', escapechar='\\')
except pd.errors.ParserError as e:
    print(f"Error parsing CSV: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

# Check if df was created before proceeding
if df is not None:
    print("Shape of the dataset:", df.shape)
    display(df.head())
    print("\nDataset Information:")
    print(df.info())
    print("\nStatistical Summary:")
    display(df.describe().T)
else:
    print("Error: DataFrame 'df' was not created. Check file download and processing.")
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1iBKEawZyX_S68hq3vh0kmyoExDnyIkqb
# To: /content/vegalite_1736783450.3959472_zone_characteristics_bar_chart.json
# 100%|██████████| 56.9k/56.9k [00:00<00:00, 55.7MB/s]
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# First few lines of the file:
# ,path,crop,croplabel
#
# 0,/kaggle/input/kag2/sugarcane/sugarcane037ahs.jpeg,sugarcane,3
#
# 1,/kaggle/input/kag2/sugarcane/sugarcane034a.jpeg,sugarcane,3
#
# 2,/kaggle/input/kag2/sugarcane/sugarcane032arot.jpeg,sugarcane,3
#
# 3,/kaggle/input/kag2/sugarcane/sugarcane036ahs.jpeg,sugarcane,3
#
# Error: DataFrame 'df' was not created. Check file download and processing.
# Shape of the dataset: (4, 4)
#    index                                               path      label  class
# 0      0  /kaggle/input/kag2/sugarcane/sugarcane037ahs.jpeg  sugarcane      3
# 1      1    /kaggle/input/kag2/sugarcane/sugarcane034a.jpeg  sugarcane      3
# ...

# %%
# Out:
# Shape of the dataset: (4, 4)
#    index                                               path      label  class
# 0      0  /kaggle/input/kag2/sugarcane/sugarcane037ahs.jpeg  sugarcane      3
# 1      1    /kaggle/input/kag2/sugarcane/sugarcane034a.jpeg  sugarcane      3
# 2      2  /kaggle/input/kag2/sugarcane/sugarcane032arot....  sugarcane      3
# 3      3  /kaggle/input/kag2/sugarcane/sugarcane036ahs.jpeg  sugarcane      3
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   4 non-null      int64
#  1   path    4 non-null      object
#  2   label   4 non-null      object
#  3   class   4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 260.0+ bytes
# None
#
# Statistical Summary:
#        count  mean       std  min   25%  50%   75%  max
# index    4.0   1.5  1.290994  0.0  0.75  1.5  2.25  3.0
# ...
