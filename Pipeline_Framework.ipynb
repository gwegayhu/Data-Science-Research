# %% [markdown]
# <a href="https://colab.research.google.com/github/gwegayhu/dashboards-app/blob/master/Pipeline_Framework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ["KAGGLE_CONFIG_DIR"] = "/path/to/kaggle.json"

# %%
import os

# Set the path to the kaggle.json file
kaggle_json_path = "https://drive.google.com/drive/home/edtechdata.csv"

# Set the environment variable
os.environ["KAGGLE_CONFIG_DIR"] = os.path.dirname(kaggle_json_path)

# %%
# !wget https://drive.google.com/drive/home/edtechdata.csv -O edtechdata.csv # Download the file from the provided URL
import csv

with open('edtechdata.csv', 'r') as csvfile: # Open the file for reading
    reader = csv.reader(csvfile)
    header = next(reader) # Read the header row
    print(f"Number of columns in header: {len(header)}") # Print the number of columns
# Out:
# --2025-01-14 12:43:27--  https://drive.google.com/drive/home/edtechdata.csv
# Resolving drive.google.com (drive.google.com)... 74.125.137.101, 74.125.137.113, 74.125.137.138, ...
# Connecting to drive.google.com (drive.google.com)|74.125.137.101|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://accounts.google.com/ServiceLogin?service=wise&passive=1209600&osid=1&continue=https://drive.google.com/drive/home/edtechdata.csv&followup=https://drive.google.com/drive/home/edtechdata.csv [following]
# --2025-01-14 12:43:28--  https://accounts.google.com/ServiceLogin?service=wise&passive=1209600&osid=1&continue=https://drive.google.com/drive/home/edtechdata.csv&followup=https://drive.google.com/drive/home/edtechdata.csv
# Resolving accounts.google.com (accounts.google.com)... 142.250.141.84, 2607:f8b0:4023:c0d::54
# Connecting to accounts.google.com (accounts.google.com)|142.250.141.84|:443... connected.
# ...

# %%
# !head edtechdata.csv
# Out:
# <!doctype html><html lang="en-US" dir="ltr"><head><base href="https://accounts.google.com/v3/signin/"><link rel="preconnect" href="//www.gstatic.com"><meta name="referrer" content="origin"><style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.SxK6Sxz7nE8.L.W.O/am=iQ2mZLgGACh_IAhQAQAQAFAAAAAAAAAAAAgMAABgQQ/d=1/ed=1/rs=AOaEmlGSGgbrbrSTCPwl83TtpXv1oh2UfA/m=identifierview,_b,_tp" nonce="jE8aE6X-3TGlYC8z5EFcAA">@-webkit-keyframes quantumWizBoxInkSpread{0%{-webkit-transform:translate(-50%,-50%) scale(0.2);-webkit-transform:translate(-50%,-50%) scale(0.2);transform:translate(-50%,-50%) scale(0.2)}to{-webkit-transform:translate(-50%,-50%) scale(2.2);-webkit-transform:translate(-50%,-50%) scale(2.2);transform:translate(-50%,-50%) scale(2.2)}}@keyframes quantumWizBoxInkSpread{0%{-webkit-transform:translate(-50%,-50%) scale(0.2);-webkit-transform:translate(-50%,-50%) scale(0.2);transform:translate(-50%,-50%) scale(0.2)}to{-webkit-transform:translate(-
# ...

# %%
import polars as pl

# Read the CSV, handling ragged lines
data = pl.read_csv('edtechdata.csv', infer_schema_length=10000, truncate_ragged_lines=True)

# Inspect the data types of each column
print(data.dtypes)
# Out:
# [String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, String, Strin
# ...

# %%
# !pip install --upgrade polars
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 51.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: polars
#     Found existing installation: polars 1.9.0
#     Uninstalling polars-1.9.0:
#       Successfully uninstalled polars-1.9.0
# ...
